# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import os

#importacion de librerias para ML
import tensorflow as tf
from tensorflow import keras

#Se usa datetime para nombrar archivos
import datetime

import numpy as np
import matplotlib.pyplot as plt

#para cargar imagenes desde internet
from PIL import Image
import requests
from io import BytesIO

#para manejo de imagenes
import cv2

# %%
print(tf.__version__)
# Out:
# 2.13.0

# %% [markdown]
# ## Importamos el dataset

# %% [markdown]
# Usamos 60.000 imagenes para entrenar la red y 10.000 imagenes para evaluar con que precision aprendió la red para clasificar las imágenes. Podemos acceder al fashion MNIST directamente desde Tensorflow.
#
# Importamos y cargamos los datos de Fashion MNIST directamente desde TensorFlow:

# %%
fashion_mnist = keras.datasets.fashion_mnist

# %%
(train_images,train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# ...
# 4422102/4422102 [==============================] - 2s 0us/step

# %%
plt.figure()
plt.imshow(train_images[1])
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# Las etiquetas son una matriz de enteros, que van de 0 a 9. Estas corresponden a la clase de vestimenta que representa la imagen:

# %%
class_names = ['camiseta','pantalon','sueter','abrigo','sandalia','camisa','zapatilla deportiva','bolso', 'botines']
